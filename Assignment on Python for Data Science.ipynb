# %% [markdown]
# ### Assignment on Python for Data Science

# %% [markdown]
# ##### Do the following operation on Iris dataset:

# %% [markdown]
# ## 1. Read the dataset to python environment.

# %% [markdown]
# ##### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Load  iris data into pandas dartaframe from a excel file using pd.read_excel() function

# %%
filename=r"C:\Users\USER\Downloads\iris.xls"
iris_data = pd.read_excel(filename)

# %%
iris_data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Data Inspection

# %% [markdown]
# #### shape -Return a tuple representing the dimensionality of the DataFrame.

# %%
iris_data.shape
# Out:
# (150, 5)

# %% [markdown]
# #### head() -view the first five rows of dataframe

# %%
iris_data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# #### info()- Return a summary of the DataFrame

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## 2. Display the columns in the dataset.

# %% [markdown]
# #### columns -The column labels of the DataFrame.

# %%
iris_data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ## 3. Calculate the mean of each column of the dataset.

# %% [markdown]
# #### mean()

# %% [markdown]
# ##### Method 1:Mean of a Single Column

# %%
#mean of column SL
iris_data['SL'].mean()
# Out:
# 5.843333333333335

# %%
#mean of column SW
iris_data['SW'].mean()
# Out:
# 3.0540000000000007

# %%
#mean of column PL
iris_data['PL'].mean()
# Out:
# 3.7586666666666693

# %%
#mean of column PW
iris_data['PW'].mean()
# Out:
# 1.1986666666666672

# %% [markdown]
# ##### Method 2:Mean of Multiple Columns

# %%
#Displaying mean of multiple colums SL,SW,PL,PW in a single code
iris_data[['SL','SW','PL','PW']].mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ##### Method 3:Mean of All Columns

# %%
iris_data.mean()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12420\3459193012.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   iris_data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ## 4. Check for the null values present in the dataset.

# %% [markdown]
# #### Method1: checking to make sure we dont have null in our dataframe before plotting using isnull().sum().

# %%
iris_data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# #### Method 2: checking to make sure we dont have nans in our dataframe before plotting using: isna().sum().

# %%
iris_data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset

# %% [markdown]
# ### 1.Scatter Plot

# %%
sns.scatterplot(data=iris_data,x='SL', y='SW')
plt.show()

# %% [markdown]
# ### 2. Pairplot to examine the correlations

# %%
plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
sns.pairplot(data = iris_data, hue="Classification", height=3);
plt.show()

# %% [markdown]
# ###  3.Count Plot - displays the number of observations for a categorical variable using bars.

# %%
sns.countplot(x=iris_data.Classification);

# %% [markdown]
# ###  4.Box Plot-shows the distribution of quantitative data across a categorical variable.

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='Classification',y='SW',data=iris_data ,palette='YlGnBu');

# %% [markdown]
# ### 5.violin plot-It shows the distribution of quantitative data across several levels of categorical variables. The violin plot also features a kde of the underlying distribution

# %%
sns.violinplot(x='Classification', y='PL', data=iris_data, palette='OrRd');
